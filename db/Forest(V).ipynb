# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("forestfires.csv")

# %%
df
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00
#
# [517 rows x 13 columns]

# %% [markdown]
# # 1 Pie

# %%
sizes=[df['temp'].mean(),df['RH'].mean(),df['wind'].mean(),df['rain'].mean()]

# %%
labels=['Temprature','Relative Humidity','Wind','Rain']

# %%
colors=["red",'blue','yellow','green']

# %%
explode=(0.1,0,0,0)

# %%
plt.pie(sizes,explode=explode,colors=colors,labels=labels,autopct="%1.1f%%")
plt.show()

# %%
y_bar=df.groupby('month')['temp'].mean()
y_bar
# Out:
# month
# apr    12.044444
# aug    21.631522
# dec     4.522222
# feb     9.635000
# jan     5.250000
# jul    22.109375
# jun    20.494118
# mar    13.083333
# may    14.650000
# nov    11.800000
# oct    17.093333
# sep    19.612209
# Name: temp, dtype: float64

# %%
x_bar=y_bar.index
x_bar
# Out:
# Index(['apr', 'aug', 'dec', 'feb', 'jan', 'jul', 'jun', 'mar', 'may', 'nov',
#        'oct', 'sep'],
#       dtype='object', name='month')

# %% [markdown]
# # 2 Bar

# %%
plt.bar(x_bar,y_bar)

plt.xlabel("Month")
plt.ylabel("Temprature")
plt.title("Monthwise temp")
plt.show()

# %% [markdown]
# # 3 Hist

# %%
plt.hist(df['temp'],bins='auto',color="orange",alpha=0.8)
plt.show()

# %% [markdown]
# # 4 Line plot

# %%
x_line=df.iloc[:20,8]
y_line=df.iloc[:20,9]

# %%
plt.plot(x_line,label='Temprature',marker="*",linestyle='dotted')
plt.plot(y_line,label="Relative humidity",marker="o",linestyle='dashed')
plt.legend()
plt.show()

# %% [markdown]
# # 5 Scatter

# %%
plt.scatter(df['DMC'],df['DC'],color='red',marker='+')
# plt.ylim(0,500)
# The DMC is a numeric rating of the average moisture content of loosely compacted organic layers (duff layers) within the soil.
#The DC is a numeric rating of the average moisture content of deep organic layers in the soil.

# %% [markdown]
# # 6 Box plot

# %%
#daywise
df.boxplot(column='temp', by='day', grid=False)
# Out:
# <Axes: title={'center': 'temp'}, xlabel='day'>

# %% [markdown]
# # 7 heatmap

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LB=LabelEncoder()
df['day']=LB.fit_transform(df['day'])

# %%
df['month']=LB.fit_transform(df['month'])

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
sns.displot(df['month'],  color='red')
plt.show()
# Out:
# C:\Python\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Python\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
